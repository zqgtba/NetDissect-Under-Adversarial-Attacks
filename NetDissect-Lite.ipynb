# %%
# !/opt/bin/nvidia-smi
# Out:
# Tue Jan 10 08:47:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# **1.** 安装环境

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# %%
# !conda update -n base conda

# %%
# !conda install scipy=1.2.0

# %%
# !conda install pytorch==1.8.0 torchvision==0.9.0 torchaudio==0.8.0 cudatoolkit=11.1 -c pytorch -c conda-forge

# %% [markdown]
# **2.** 下载数据集

# %%
# !git clone https://github.com/CSAILVision/NetDissect-Lite
# Out:
# Cloning into 'NetDissect-Lite'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 147 (delta 50), reused 49 (delta 49), pack-reused 85
# Receiving objects: 100% (147/147), 62.56 KiB | 279.00 KiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
cd /content/NetDissect-Lite

# %%
# !./script/dlzoo_example.sh

# %%
# !chmod u+x /content/NetDissect-Lite/script/dlbroden.sh

# %%
# !./script/dlbroden.sh

# %% [markdown]
# **3.** 生成Broden对抗样本

# %%
# !pip install cleverhans

# %%
# !pip install opencv-python

# %%
# !python /content/gen_adv_data.py

# %% [markdown]
# **Notice:** /loader/data_loader.py line517 and line544 should be 'return'

# %%
# !python main.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# extracting feature from batch 445 / 495
# extracting feature from batch 446 / 495
# extracting feature from batch 447 / 495
# extracting feature from batch 448 / 495
# extracting feature from batch 449 / 495
# extracting feature from batch 450 / 495
# extracting feature from batch 451 / 495
# extracting feature from batch 452 / 495
# extracting feature from batch 453 / 495
# extracting feature from batch 454 / 495
# extracting feature from batch 455 / 495
# extracting feature from batch 456 / 495
# extracting feature from batch 457 / 495
# extracting feature from batch 458 / 495
# extracting feature from batch 459 / 495
# extracting feature from batch 460 / 495
# extracting feature from batch 461 / 495
# extracting feature from batch 462 / 495
# extracting feature from batch 463 / 495
# extracting feature from batch 464 / 495
# extracting feature from batch 465 / 495
# extracting feature from batch 466 / 495
# extracting feature from batch 467 / 495
# ...

# %%
# !git clone https://github.com/yjn870/SRCNN-pytorch.git
# Out:
# Cloning into 'SRCNN-pytorch'...
# remote: Enumerating objects: 42, done.
# remote: Total 42 (delta 0), reused 0 (delta 0), pack-reused 42
# Unpacking objects: 100% (42/42), done.

# %%
cd /content
# Out:
# /content

# %%
# !python download.py
# Out:
# Traceback (most recent call last):
#   File "download.py", line 17, in <module>
#     make_targz_one_by_one('NetDissect', '/content/NetDissect-Lite')
#   File "download.py", line 14, in make_targz_one_by_one
#     files.download(output_filename)
#   File "/usr/local/lib/python3.7/dist-packages/google/colab/files.py", line 144, in download
#     comm_manager = _IPython.get_ipython().kernel.comm_manager
# AttributeError: 'NoneType' object has no attribute 'kernel'

# %%
# !python main.py
# Out:
# /content/NetDissect-Lite/loader/data_loader.py:150: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[list(np.indices(arr.shape)) + [arr]] = 1
# Traceback (most recent call last):
#   File "main.py", line 8, in <module>
#     model = loadmodel(hook_feature)
#   File "/content/NetDissect-Lite/loader/model_loader.py", line 11, in loadmodel
#     model = torchvision.models.__dict__[settings.MODEL](num_classes=settings.NUM_CLASSES)
# KeyError: 'ADMM-CSNET'

# %%
cd /content/NetDissect-Lite/dataset
# Out:
# /content/NetDissect-Lite/dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat
m=loadmat("/content/NetDissect-Lite/dataset/new01.mat")
m['data']
# Out:
# array([[(array([[(array([[ 3.98937113e-03+5.68990197e-03j,  7.57870762e-03+9.21992127e-03j,
#         -7.43497042e-03+1.85127861e-02j, ...,
#         -1.13649396e-02-4.00137020e-04j, -9.00314771e-04-3.61920307e-03j,
#          0.00000000e+00+0.00000000e+00j],
#        [-1.97493647e-03+4.55069284e-03j,  8.88055170e-05-5.93195439e-03j,
#         -4.65873294e-03+4.92722321e-05j, ...,
#         -5.63922801e-03+1.21593223e-03j,  8.00732880e-04+1.79110586e-02j,
#          0.00000000e+00+0.00000000e+00j],
#        [-1.16759633e-03-6.38084714e-03j, -6.96089873e-03+1.65625699e-03j,
#         -4.25529536e-03-2.47458112e-03j, ...,
#          6.43702106e-03+3.74170445e-04j, -4.07392475e-03+5.72020813e-04j,
#          0.00000000e+00+0.00000000e+00j],
#        ...,
#        [-7.99366116e-03+1.14508399e-02j,  1.25485261e-03+1.69103896e-03j,
#          3.61510807e-03-6.50954392e-03j, ...,
#          7.31318514e-03+3.28020428e-03j, -7.34012544e-04-3.10354570e-03j,
# ...
